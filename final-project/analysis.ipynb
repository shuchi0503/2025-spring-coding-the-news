# %%
import pandas as pd

# %%
df = pd.read_csv("911_raw_data.csv")
df.head()
# Out:
#   Month Name     Agency                                        Description  \
# 0  2025 / 03  Aggregate  Combined average response time to life threate...
# 1  2025 / 03  Aggregate  Combined average response time to life threate...
# 2  2025 / 03  Aggregate  Combined average response time to life threate...
# 3  2025 / 03  Aggregate  Combined average response time to life threate...
# 4  2025 / 03  Aggregate  Combined average response time to life threate...
#
#          Borough  # of Incidents  Response Times
# 0       Brooklyn           13615          567.01
# 1          Bronx           11039          683.05
# 2      Manhattan           10868          642.23
# 3         Queens            9819          601.25
# 4  Staten Island            2398          550.99

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10166 entries, 0 to 10165
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Month Name      10166 non-null  object
#  1   Agency          10166 non-null  object
#  2   Description     10166 non-null  object
#  3   Borough         10166 non-null  object
#  4   # of Incidents  10166 non-null  int64
#  5   Response Times  10166 non-null  float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 476.7+ KB

# %%
df["Description"].value_counts()
# Out:
# Description
# Combined average response time to life threatening medical emergencies by ambulance and fire units                                                         822
# Average response time to life threatening medical emergencies by ambulance units                                                                           822
# Average response time to life threatening and non-life threatening medical emergencies by ambulance units combined                                         822
# Average response time to non-fire emergencies                                                                                                              820
# Average response time to life threatening medical emergencies by fire units                                                                                817
# Percentage of response time of less than 10 minutes to Advanced Life Support medical emergencies by Advanced Life Support ambulances                       804
# ...

# %%
df["Borough"].value_counts()
# Out:
# Borough
# Manhattan        1778
# Queens           1778
# Brooklyn         1777
# Bronx            1777
# Staten Island    1777
# Unspecified      1279
# Name: count, dtype: int64

# %%
df.groupby("Borough")
